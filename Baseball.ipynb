# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
# columns infrmation:

# W – Win: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work (also related: winning percentage)
# R – Runs scored: number of times a player crosses home plate
# AB – At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction
# H – Hit: reaching base because of a batted, fair ball without error by the defense
# 2B – Double: hits on which the batter reaches second base safely without the contribution of a fielding error
# 3B – Triple: hits on which the batter reaches third base safely without the contribution of a fielding error
# HR – Home runs: hits on which the batter successfully touched all four bases, without the contribution of a fielding error
# BB – Base on balls (also called a "walk"): hitter not swinging at four pitches called out of the strike zone and awarded first base.
# SO – Strikeout: number of batters who received strike three
# SB – Stolen base: number of bases advanced by the runner while the ball is in the possession of the defense
# RA – Run average: number of runs allowed times nine divided by innings pitched
# ER – Earned run: number of runs that did not occur as a result of errors or passed balls
# ERA – Earned run average: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched
# CG – Complete game: number of games where player was the only pitcher for their team
# SHO – Shutout: number of complete games pitched with no runs allowed
# SV – Save: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game 
#       (b) the potential tying run was on base, at bat, or on deck; 
#       (c) the pitcher pitched three or more innings
# E – Errors: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result

# %%
# EDA Checking:-

df.isnull().sum()


# Hence there are NO any null values in the dataset.
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
# Visualization of DATA:


import seaborn as sns
import matplotlib.pyplot as plt
from  plotly.subplots import make_subplots

# %%
df_continuous= df[['W','R','AB','H','2B','3B','HR','BB','SO','SB','RA','ER','ERA','CG','SHO','SV','E']].copy

# %%
# def Shubh(df,i):
#     plt.figure(figsize=(30,10))
#     plt.subplot(1,3,1)
#     sns.histplot(x=i,data=df,kde=True)
#     plt.subplot(1,3,2)
#     sns.regplot(x=i,y='W',data=df)
#     plt.subplot(1,3,3)
#     sns.boxplot(y=i,data=df)
#     plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="R",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="R",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="R",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="AB",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="AB",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="AB",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="H",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="H",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="H",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="2B",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="2B",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="2B",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="3B",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="3B",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="3B",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="HR",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="HR",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="HR",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="BB",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="BB",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="BB",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="SO",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="SO",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="SO",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="SB",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="SB",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="SB",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="RA",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="RA",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="RA",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="ER",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="ER",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="ER",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="ERA",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="ERA",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="ERA",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="CG",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="CG",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="CG",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="SHO",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="SHO",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="SHO",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="SV",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="SV",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="SV",data=df)
plt.show()

# %%
plt.figure(figsize=(30,10))
plt.subplot(1,3,1)
sns.histplot(x="E",data=df,kde=True)
plt.subplot(1,3,2)
sns.regplot(x="E",y='W',data=df)
plt.subplot(1,3,3)
sns.boxplot(y="E",data=df)
plt.show()

# %%
# 1) From above Visualization I conclude that R, HR, 2B, SV, SHO, BB this columns datas are highly positively linearly corelated and Having the randomness in some columns
# 2) The column data SB, RA, ER this column data are highly negetively corelated.
# 3) The Column AB, H, SO, ERA, CG, E this columns are having too less features and are very less corelated to W
# 4) The data set has the outliners present and is in the randomness.

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize = (29,9))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor='black',fmt='0.2f')

# df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='white')
# Out:
# <AxesSubplot:>

# %%
# SV has the 67% correleated with W and considered as good bond.

# %%
# Describing the datatset:

df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
plt.figure(figsize=(25,12))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor='black',fmt='0.2f')
plt.yticks(fontsize=12)
plt.title("variable summary")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
# From above we have the column data type.



# Also we had done the outliners checking in visualizton part 
# so more outliers are present in the E column
# while also the outers are SV, SHO, ERA, R column
# while

# %%
x=df.drop("W",axis=1)
y=df["W"]

# %%
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# ...

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
x.skew()
# Out:
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
# here the skewness is present in the R, H, CG, SV, E

# %%
# as the error column is not having much more corelation with the dependent variable let drop the column:

df1=x.drop(['E'],axis=1)
df1
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12  35
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10  34
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4  48
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10  43
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12  60
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10  40
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9  45
# ...

# %%
# Removing the outliers:

# Z Score Technique:

from scipy.stats import zscore
z=np.abs(zscore(df1))
z.shape
# Out:
# (30, 15)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5]), array([0]))

# %%
df_new=df1[(z<3).all(axis=1)]
print(df1.shape)
print(df_new.shape)
# Out:
# (30, 15)
# (29, 15)

# %%
# checking the still outliers are present or not if they ARE present the they help in testing model or not



from scipy.stats import zscore
(np.abs(zscore(df_new))<3).all()
# Out:
# R      True
# AB     True
# H      True
# 2B     True
# 3B     True
# HR     True
# BB     True
# SO     True
# SB     True
# RA     True
# ER     True
# ERA    True
# CG     True
# SHO    True
# SV     True
# dtype: bool

# %%
# percentage of data loss::


loss_percentage = (30-29)/(30*100)

print(loss_percentage)
# Out:
# 0.0003333333333333333

# %%
# Removing Sekwness by data tramsformaton technique::
# # preprocessing:

from sklearn.preprocessing import power_transform
x_new = power_transform(x,method='yeo-johnson')
# y = power_transform(y)

# %%
sh=pd.DataFrame(x_new).skew().sort_values(ascending=False)
sh
# Out:
# 7     0.094237
# 11    0.038847
# 10    0.031537
# 13    0.025632
# 8     0.015728
# 6     0.010883
# 9     0.003265
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3    -0.007991
# 12   -0.008641
# 4    -0.015477
# 15   -0.020539
# 14   -0.026307
# 5    -0.061156
# dtype: float64

# %%
sh.skew()
# Out:
# 0.8355376677035509

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
x1=scale.fit_transform(x)
x1
# Out:
# array([[ 0.        ,  0.        ,  0.        ,  1.47768528,  1.03310301,
#         -0.76462586, -1.61091476, -2.56989562,  0.93970819, -0.66033096,
#         -0.49742469, -0.50089346, -0.35984364, -0.78957937,  1.546378  ,
#         -0.3349525 ],
#        [ 0.        ,  0.        ,  0.        ,  0.08426878,  1.2033202 ,
#         -0.15858141, -0.50274883,  0.13491294, -0.53969308,  0.17546536,
#          0.25797351,  0.26180619, -0.35984364,  0.25177537,  0.36044386,
#         -0.53221128],
#        [ 0.        ,  0.        ,  0.        ,  1.67078208, -0.16026987,
#         -0.68967629,  1.1282937 , -0.90125379,  0.2119555 , -0.67462053,
#         -0.74690639, -0.63645949,  1.99351257, -0.24539345, -0.6075936 ,
#         -1.34233137],
#        [ 0.        ,  0.        ,  0.        , -0.84859969, -0.36052064,
#         -0.8790486 , -1.18120722, -0.1896282 , -0.64256433,  0.18951225,
#          0.11357524,  0.06080381,  1.22010317, -0.51075929, -0.76445333,
#          0.67852361],
# ...

# %%
x1=pd.DataFrame(data=x1,columns=x.columns)
x1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/4d/ytl5tj193_7br22pvpj_t5n40000gn/T/ipykernel_5212/2135579605.py in <module>
# ----> 1 x1=pd.DataFrame(data=x1,columns=x.columns)
#       2 x1
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
y1=pd.DataFrame(y)
y1
# Out:
#      0
# 0   20
# 1   11
# 2   10
# 3    6
# 4    5
# 5   19
# 6   15
# 7   10
# 8    9
# 9    7
# 10  16
# 11  14
# 12  13
# 13   6
# 14   3
# 15  23
# 16  22
# 17  21
# 18   3
# 19   1
# 20  17
# 21  11
# 22   4
# 23   2
# 24   0
# 25  18
# 26  12
# 27   8
# 28   5
# 29   3

# %%
from sklearn import preprocessing
from sklearn import utils
a =preprocessing.LabelEncoder()

# x1_transformed =a.fit_transform(x1)

y_transformed =a.fit_transform(y1)

print(y_transformed)

y=y_transformed
# Out:
# [20 11 10  6  5 19 15 10  9  7 16 14 13  6  3 23 22 21  3  1 17 11  4  2
#   0 18 12  8  5  3]

# %%
# x=x.reshape(x.shape[1:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/4d/ytl5tj193_7br22pvpj_t5n40000gn/T/ipykernel_5212/3671007130.py in <module>
# ----> 1 x=x.reshape(x.shape[1:])
#
# ValueError: cannot reshape array of size 480 into shape (16,)

# %%
print(x1.shape)
print(y1.shape)
# Out:
# (30, 16)
# (30, 1)

# %%
# 

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('ignore')

# %%
# Splitting the dataframe:


for i in range(0,100):
    x1_train,x1_test,y1_train,y1_test = train_test_split(x1,y1,test_size=0.2,random_state=i)
    lr.fit(x1_train,y1_train)
    pred_train=lr.predict(x1_train)
    pred_test=lr.predict(y1_test)
    print("At random state {i}, the training accuracy is :- {r2_score(y1_train,pred_train)}")
    print("At random state {i}, the testing accuracy is :- {r2_score(y1_test,pred_test)}")
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/4d/ytl5tj193_7br22pvpj_t5n40000gn/T/ipykernel_5212/3721514892.py in <module>
#       6     lr.fit(x1_train,y1_train)
#       7     pred_train=lr.predict(x1_train)
# ----> 8     pred_test=lr.predict(y1_test)
#       9     print("At random state {i}, the training accuracy is :- {r2_score(y1_train,pred_train)}")
#      10     print("At random state {i}, the testing accuracy is :- {r2_score(y1_test,pred_test)}")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     307             Predicted class label per sample.
#     308         """
# --> 309         scores = self.decision_function(X)
#     310         if len(scores.shape) == 1:
#     311             indices = (scores > 0).astype(int)
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rf= RandomForestClassifier()



for i in range(0,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=i)
    rf.fit(x_train,y_train)
    pred_train=rf.predict(x_train)
    pred_test=rf.predict(y_test)
    print("At random state {i}, the training accuracy is :- {r2_score(y_train,pred_train)}")
    print("At random state {i}, the testing accuracy is :- {r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/4d/ytl5tj193_7br22pvpj_t5n40000gn/T/ipykernel_5212/1606500792.py in <module>
#       5
#       6 for i in range(0,100):
# ----> 7     x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=i)
#       8     rf.fit(x_train,y_train)
#       9     pred_train=rf.predict(x_train)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2170         raise ValueError("At least one array required as input")
#    2171
# -> 2172     arrays = indexable(*arrays)
#    2173
#    2174     n_samples = _num_samples(arrays[0])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     354     """
# ...
